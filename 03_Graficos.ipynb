# %%
# LIBRERIAS
import pandas as pd
import numpy as np
import math as math
import os
import matplotlib.pyplot as plt

# %%
# IMPORTACIÓN DE LA BASE DE DATOS
df = pd.read_csv("df_final.csv")
del df["Unnamed: 0"]

# %%
# DESCRIPTIVA PARA LAS VARIABLES NÚMERICAS
df.describe()
# Out:
#        host_response_rate  host_acceptance_rate  host_listings_count  \
# count        13252.000000          13252.000000         13252.000000
# mean            90.607757             82.597299            26.695819
# std             16.657503             23.955375           128.798159
# min              0.000000              0.000000             0.000000
# 25%             89.000000             74.600000             1.000000
# 50%             98.000000             93.400000             3.000000
# 75%            100.000000             99.600000            16.000000
# max            100.000000            100.000000          2178.000000
#
#        host_total_listings_count      bedrooms          beds         price  \
# count               13252.000000  13252.000000  13252.000000  13252.000000
# mean                   26.695819      1.678765      2.314066     96.162843
# std                   128.798159      0.984274      1.826875     94.442147
# min                     0.000000      1.000000      0.000000      8.000000
# 25%                     1.000000      1.000000      1.000000     40.000000
# 50%                     3.000000      1.000000      2.000000     70.000000
# 75%                    16.000000      2.000000      3.000000    121.000000
# max                  2178.000000     12.000000     20.000000    999.000000
#
#        review_scores_rating  review_scores_accuracy  \
# count          13252.000000            13252.000000
# mean               4.487857                4.642631
# std                0.667453                0.475530
# min                0.000000                0.000000
# 25%                4.360000                4.540000
# 50%                4.660000                4.780000
# 75%                4.858000                4.930000
# max                5.000000                5.000000
#
#        review_scores_cleanliness  ...  government_id  offline_government_id  \
# count               13252.000000  ...   13252.000000           13252.000000
# mean                    4.565839  ...       0.697178               0.507546
# std                     0.511794  ...       0.459496               0.499962
# min                     0.000000  ...       0.000000               0.000000
# 25%                     4.430000  ...       0.000000               0.000000
# 50%                     4.700000  ...       1.000000               1.000000
# 75%                     4.890000  ...       1.000000               1.000000
# max                     5.000000  ...       1.000000               1.000000
#
#              selfie  identity_manual      facebook    work_email  \
# count  13252.000000     13252.000000  13252.000000  13252.000000
# mean       0.349381         0.327271      0.128132      0.174691
# std        0.476793         0.469235      0.334249      0.379717
# min        0.000000         0.000000      0.000000      0.000000
# 25%        0.000000         0.000000      0.000000      0.000000
# 50%        0.000000         0.000000      0.000000      0.000000
# 75%        1.000000         1.000000      0.000000      0.000000
# max        1.000000         1.000000      1.000000      1.000000
#
#              google  host_is_superhost_t  host_has_profile_pic_t  \
# count  13252.000000         13252.000000            13252.000000
# mean       0.040899             0.177860                0.996529
# std        0.198065             0.382409                0.058817
# min        0.000000             0.000000                0.000000
# 25%        0.000000             0.000000                1.000000
# 50%        0.000000             0.000000                1.000000
# 75%        0.000000             0.000000                1.000000
# max        1.000000             1.000000                1.000000
#
#        host_identity_verified_t
# count              13252.000000
# mean                   0.786221
# std                    0.409988
# min                    0.000000
# 25%                    1.000000
# 50%                    1.000000
# 75%                    1.000000
# max                    1.000000
#
# [8 rows x 91 columns]

# %%
df[df.iloc[:,25:90].columns] = df[df.iloc[:,25:90].columns].astype("int")

# %% [markdown]
# Crearemos dos carpetas para guardar todos los graficos.

# %%
os.mkdir("Graficos float")
os.mkdir("Graficos integer")

# %% [markdown]
# Pasamos a hacer todos los graficos para las variables "float"

# %%
df.select_dtypes(['float']).columns
var_float = df.select_dtypes(['float']).columns

# %%
os.chdir("E:\Data\TFG\Graficos float")

for col in var_float:
    plt.hist(x = col, data = df)
    plt.title("Histograma de " + col)
    plt.savefig("Histograma de " + col + ".png")
    plt.show()

for col in var_float:
    plt.boxplot(x = col, data = df)
    plt.title("Boxplot de " + col)
    plt.savefig("Boxplot de " + col + ".png")
    plt.show()

# %%
# Cambiamos de nombre la columna "Pack \u2019n Play/travel crib" ya que da problemas para guardar el grafico
df.rename(columns = {'Pack \\u2019n Play/travel crib' : "Pack u2019n Play travel crib"}, inplace = True)

df.select_dtypes(['int']).columns
var_int = df.select_dtypes(['int']).columns

# %%
os.chdir("E:\Data\TFG\Graficos integer")

#df.columns = df.columns.str.replace("Pack \u2019n Play/travel crib", "Pack u2019n Play travel crib")

for col in var_int:
    counts = df[col].value_counts().sort_index()
    counts.plot(kind = "pie",autopct='%.0f%%')
    plt.title("Pieplot de " + col)
    plt.savefig("Pieplot de " + col + ".png")
    plt.show()
